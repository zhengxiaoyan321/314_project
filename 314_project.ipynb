# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
charlotte = pd.read_csv('data/nc_charlotte_2020_04_01.csv')
durham = pd.read_csv('data/nc_durham_2020_04_01.csv')
fayetteville = pd.read_csv('data/nc_fayetteville_2020_04_01.csv')
greensboro = pd.read_csv('data/nc_greensboro_2020_04_01.csv')
raleigh = pd.read_csv('data/nc_raleigh_2020_04_01.csv')
winston_salem = pd.read_csv('data/nc_winston-salem_2020_04_01.csv')
# Out:
# /Users/brandon/opt/anaconda3/envs/cse217a/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
combined = pd.concat([charlotte, durham, fayetteville, greensboro, raleigh, winston_salem], axis=0)
combined
# Out:
#         raw_row_number        date      time             location  \
# 0                 3254  2000-01-01  17:20:00              Unknown
# 1                 3259  2000-01-02  11:40:00              Unknown
# 2                 3281  2000-01-02  02:41:00              Unknown
# 3                 3282  2000-01-23  03:35:00              Unknown
# 4                 3283  2000-01-02  16:45:00              Unknown
# ...                ...         ...       ...                  ...
# 452555        20278399  2015-12-19  02:27:00  nan, Forsyth County
# 452556        20278400  2015-12-09  23:38:00  nan, Forsyth County
# 452557        20278401  2015-12-11  01:24:00  nan, Forsyth County
# 452558        20278402  2015-12-11  02:21:00  nan, Forsyth County
# 452559        20278403  2015-12-11  00:36:00  nan, Forsyth County
#
#            county_name  subject_age subject_race subject_sex officer_id_hash  \
# 0                  NaN         38.0        black      female      22e35044ed
# 1                  NaN         33.0     hispanic        male      22e35044ed
# 2                  NaN         23.0        white        male      22e35044ed
# 3                  NaN         23.0        white      female      22e35044ed
# 4                  NaN         23.0        white      female      22e35044ed
# ...                ...          ...          ...         ...             ...
# 452555  Forsyth County         24.0        black        male      0a7f06db99
# 452556  Forsyth County         37.0        black        male      223001a5be
# 452557  Forsyth County         21.0     hispanic        male      b17198e1b4
# 452558  Forsyth County         27.0        white        male      0f4172ddc4
# 452559  Forsyth County         42.0        black        male      c579308c2c
#
#                                    department_name       type  arrest_made  \
# 0       UNC Charlotte University Police Department  vehicular        False
# 1       UNC Charlotte University Police Department  vehicular        False
# 2       UNC Charlotte University Police Department  vehicular        False
# 3       UNC Charlotte University Police Department  vehicular        False
# 4       UNC Charlotte University Police Department  vehicular        False
# ...                                            ...        ...          ...
# 452555             Winston-Salem Police Department  vehicular        False
# 452556             Winston-Salem Police Department  vehicular        False
# 452557             Winston-Salem Police Department  vehicular         True
# 452558             Winston-Salem Police Department  vehicular         True
# 452559             Winston-Salem Police Department  vehicular        False
#
#         citation_issued  warning_issued   outcome contraband_found  \
# 0                 False            True   warning              NaN
# 1                  True           False  citation              NaN
# 2                  True           False  citation              NaN
# 3                  True           False  citation              NaN
# 4                 False            True   warning              NaN
# ...                 ...             ...       ...              ...
# 452555             True           False  citation             True
# 452556             True           False  citation             True
# 452557            False           False    arrest            False
# 452558            False           False    arrest            False
# 452559             True           False  citation            False
#
#        contraband_drugs contraband_weapons  frisk_performed  search_conducted  \
# 0                   NaN                NaN            False             False
# 1                   NaN                NaN            False             False
# 2                   NaN                NaN            False             False
# 3                   NaN                NaN            False             False
# 4                   NaN                NaN            False             False
# ...                 ...                ...              ...               ...
# 452555             True              False            False              True
# 452556             True              False            False              True
# 452557            False              False            False              True
# 452558            False              False            False              True
# 452559            False              False            False              True
#
#         search_person  search_vehicle    search_basis reason_for_frisk  \
# 0               False           False             NaN              NaN
# 1               False           False             NaN              NaN
# 2               False           False             NaN              NaN
# 3               False           False             NaN              NaN
# 4               False           False             NaN              NaN
# ...               ...             ...             ...              ...
# 452555           True            True  probable cause              NaN
# 452556           True            True  probable cause              NaN
# 452557           True            True           other              NaN
# 452558           True            True  probable cause              NaN
# 452559          False            True         consent              NaN
#
#                           reason_for_search                reason_for_stop  \
# 0                                       NaN        Safe Movement Violation
# 1                                       NaN   Vehicle Regulatory Violation
# 2                                       NaN    Vehicle Equipment Violation
# 3                                       NaN   Vehicle Regulatory Violation
# 4                                       NaN        Safe Movement Violation
# ...                                     ...                            ...
# 452555  Observation of Suspected Contraband  Other Motor Vehicle Violation
# 452556           Other Official Information    Vehicle Equipment Violation
# 452557  Observation of Suspected Contraband    Vehicle Equipment Violation
# 452558           Other Official Information         Driving While Impaired
# 452559           Other Official Information            Seat Belt Violation
#
#        raw_Ethnicity raw_Race raw_action_description
# 0                  N        B         Verbal Warning
# 1                  H        W        Citation Issued
# 2                  N        W        Citation Issued
# 3                  N        W        Citation Issued
# 4                  N        W         Verbal Warning
# ...              ...      ...                    ...
# 452555             N        B        Citation Issued
# 452556             N        B        Citation Issued
# 452557             H        W         On-View Arrest
# 452558             N        W         On-View Arrest
# 452559             N        B        Citation Issued
#
# [4320466 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(combined, test_size=0.2, stratify = combined['department_name'])

# %%
print(combined.shape)
print(combined.dtypes)
# Out:
# (4320466, 29)
# raw_row_number              int64
# date                       object
# time                       object
# location                   object
# county_name                object
# subject_age               float64
# subject_race               object
# subject_sex                object
# officer_id_hash            object
# department_name            object
# type                       object
# arrest_made                  bool
# citation_issued              bool
# warning_issued               bool
# outcome                    object
# contraband_found           object
# contraband_drugs           object
# contraband_weapons         object
# frisk_performed              bool
# search_conducted             bool
# search_person                bool
# search_vehicle               bool
# search_basis               object
# reason_for_frisk           object
# reason_for_search          object
# reason_for_stop            object
# raw_Ethnicity              object
# raw_Race                   object
# raw_action_description     object
# dtype: object

# %%
combined.isnull().sum()
# Out:
# raw_row_number                  0
# date                            0
# time                       168848
# location                        0
# county_name                  2351
# subject_age                    46
# subject_race                    5
# subject_sex                     5
# officer_id_hash                 0
# department_name                 0
# type                            0
# arrest_made                     0
# citation_issued                 0
# warning_issued                  0
# outcome                    139872
# contraband_found          4106216
# contraband_drugs          4106216
# contraband_weapons        4106216
# frisk_performed                 0
# search_conducted                0
# search_person                   0
# search_vehicle                  0
# search_basis              4111192
# reason_for_frisk          4315490
# reason_for_search         4106220
# reason_for_stop                 0
# raw_Ethnicity                   5
# raw_Race                        5
# raw_action_description          0
# dtype: int64

# %%
percent_missing = combined.isnull().sum() * 100 / len(combined)
missing_value_df = pd.DataFrame({'column_name': combined.columns,
                                 'percent_missing': percent_missing})
stat_df = combined.describe(include='all').T
stat_df['missing_rate'] = missing_value_df['percent_missing']
stat_df = stat_df.drop(columns = ['count'])
stat_df
# Out:
#                        unique                                      top  \
# raw_row_number            NaN                                      NaN
# date                     5841                               2010-02-19
# time                    84732                                 23:00:00
# location                  412       Charlotte Area, Mecklenburg County
# county_name                39                       Mecklenburg County
# subject_age               NaN                                      NaN
# subject_race                6                                    black
# subject_sex                 2                                     male
# officer_id_hash         20355                               8f589487ed
# department_name            11  Charlotte-Mecklenburg Police Department
# type                        1                                vehicular
# arrest_made                 2                                    False
# citation_issued             2                                     True
# warning_issued              2                                    False
# outcome                     3                                 citation
# contraband_found            2                                    False
# contraband_drugs            2                                    False
# contraband_weapons          2                                    False
# frisk_performed             2                                    False
# search_conducted            2                                    False
# search_person               2                                    False
# search_vehicle              2                                    False
# search_basis                3                                  consent
# reason_for_frisk           70              Erratic/Suspicious Behavior
# reason_for_search         120               Other Official Information
# reason_for_stop            10                    Speed Limit Violation
# raw_Ethnicity               2                                        N
# raw_Race                    5                                        B
# raw_action_description      5                          Citation Issued
#
#                            freq             mean             std     min  \
# raw_row_number              NaN  10834448.086862  5487058.481485  3225.0
# date                       1698              NaN             NaN     NaN
# time                       8350              NaN             NaN     NaN
# location                1576997              NaN             NaN     NaN
# county_name             1597205              NaN             NaN     NaN
# subject_age                 NaN        34.149612       12.602286    10.0
# subject_race            2135696              NaN             NaN     NaN
# subject_sex             2662085              NaN             NaN     NaN
# officer_id_hash           17413              NaN             NaN     NaN
# department_name         1576998              NaN             NaN     NaN
# type                    4320466              NaN             NaN     NaN
# arrest_made             4204935              NaN             NaN     NaN
# citation_issued         2476444              NaN             NaN     NaN
# warning_issued          2731847              NaN             NaN     NaN
# outcome                 2476444              NaN             NaN     NaN
# contraband_found         161218              NaN             NaN     NaN
# contraband_drugs         189114              NaN             NaN     NaN
# contraband_weapons       208146              NaN             NaN     NaN
# frisk_performed         4315490              NaN             NaN     NaN
# search_conducted        4106216              NaN             NaN     NaN
# search_person           4122913              NaN             NaN     NaN
# search_vehicle          4128362              NaN             NaN     NaN
# search_basis              96962              NaN             NaN     NaN
# reason_for_frisk           1371              NaN             NaN     NaN
# reason_for_search         56574              NaN             NaN     NaN
# reason_for_stop         1384113              NaN             NaN     NaN
# raw_Ethnicity           3928549              NaN             NaN     NaN
# raw_Race                2143069              NaN             NaN     NaN
# raw_action_description  2476444              NaN             NaN     NaN
#
#                                25%         50%          75%         max  \
# raw_row_number          6039822.25  10643353.5  15595859.75  20280228.0
# date                           NaN         NaN          NaN         NaN
# time                           NaN         NaN          NaN         NaN
# location                       NaN         NaN          NaN         NaN
# county_name                    NaN         NaN          NaN         NaN
# subject_age                   24.0        31.0         42.0       110.0
# subject_race                   NaN         NaN          NaN         NaN
# subject_sex                    NaN         NaN          NaN         NaN
# officer_id_hash                NaN         NaN          NaN         NaN
# department_name                NaN         NaN          NaN         NaN
# type                           NaN         NaN          NaN         NaN
# arrest_made                    NaN         NaN          NaN         NaN
# citation_issued                NaN         NaN          NaN         NaN
# warning_issued                 NaN         NaN          NaN         NaN
# outcome                        NaN         NaN          NaN         NaN
# contraband_found               NaN         NaN          NaN         NaN
# contraband_drugs               NaN         NaN          NaN         NaN
# contraband_weapons             NaN         NaN          NaN         NaN
# frisk_performed                NaN         NaN          NaN         NaN
# search_conducted               NaN         NaN          NaN         NaN
# search_person                  NaN         NaN          NaN         NaN
# search_vehicle                 NaN         NaN          NaN         NaN
# search_basis                   NaN         NaN          NaN         NaN
# reason_for_frisk               NaN         NaN          NaN         NaN
# reason_for_search              NaN         NaN          NaN         NaN
# reason_for_stop                NaN         NaN          NaN         NaN
# raw_Ethnicity                  NaN         NaN          NaN         NaN
# raw_Race                       NaN         NaN          NaN         NaN
# raw_action_description         NaN         NaN          NaN         NaN
#
#                         missing_rate
# raw_row_number              0.000000
# date                        0.000000
# time                        3.908097
# location                    0.000000
# county_name                 0.054415
# subject_age                 0.001065
# subject_race                0.000116
# subject_sex                 0.000116
# officer_id_hash             0.000000
# department_name             0.000000
# type                        0.000000
# arrest_made                 0.000000
# citation_issued             0.000000
# warning_issued              0.000000
# outcome                     3.237429
# contraband_found           95.041044
# contraband_drugs           95.041044
# contraband_weapons         95.041044
# frisk_performed             0.000000
# search_conducted            0.000000
# search_person               0.000000
# search_vehicle              0.000000
# search_basis               95.156217
# reason_for_frisk           99.884827
# reason_for_search          95.041137
# reason_for_stop             0.000000
# raw_Ethnicity               0.000116
# raw_Race                    0.000116
# raw_action_description      0.000000
