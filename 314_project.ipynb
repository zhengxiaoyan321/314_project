# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('nc_durham_2020_04_01.csv')
data
# Out:
#         raw_row_number        date      time               location  \
# 0              1219541  2001-12-28       NaN  Durham, Durham County
# 1              1221117  2002-01-02  04:00:00  Durham, Durham County
# 2              1221124  2002-01-02       NaN  Durham, Durham County
# 3              1221133  2002-01-02  19:50:00  Durham, Durham County
# 4              1221146  2002-01-02  20:45:00  Durham, Durham County
# ...                ...         ...       ...                    ...
# 326019        20266702  2015-12-03  21:10:00     nan, Durham County
# 326020        20266703  2015-12-04  03:20:00     nan, Durham County
# 326021        20280195  2015-01-28  10:17:00  Durham, Durham County
# 326022        20280197  2015-01-28  13:41:00  Durham, Durham County
# 326023        20280228  2013-11-01  04:23:00  Durham, Durham County
#
#           county_name  subject_age            subject_race subject_sex  \
# 0       Durham County         22.0                   black      female
# 1       Durham County         28.0                hispanic        male
# 2       Durham County         21.0                   black        male
# 3       Durham County         28.0                   black      female
# 4       Durham County         36.0                   black      female
# ...               ...          ...                     ...         ...
# 326019  Durham County         23.0                   black        male
# 326020  Durham County         32.0  asian/pacific islander      female
# 326021  Durham County         31.0                   black        male
# 326022  Durham County         21.0                   black      female
# 326023  Durham County         32.0                   black      female
#
#        officer_id_hash                 department_name       type  \
# 0           5b9908c1a5        Durham Police Department  vehicular
# 1           0c140e68b5        Durham Police Department  vehicular
# 2           0c140e68b5        Durham Police Department  vehicular
# 3           41b05be9b1        Durham Police Department  vehicular
# 4           41b05be9b1        Durham Police Department  vehicular
# ...                ...                             ...        ...
# 326019      72b606b024        Durham Police Department  vehicular
# 326020      a4d178e9f0        Durham Police Department  vehicular
# 326021      6c39e1a069  Durham County Sheriff's Office  vehicular
# 326022      6c39e1a069  Durham County Sheriff's Office  vehicular
# 326023      0fbc3d0948  Durham County Sheriff's Office  vehicular
#
#         arrest_made  citation_issued  warning_issued   outcome  \
# 0             False            False            True   warning
# 1             False             True           False  citation
# 2             False            False            True   warning
# 3             False             True           False  citation
# 4             False            False            True   warning
# ...             ...              ...             ...       ...
# 326019        False             True           False  citation
# 326020        False            False           False       NaN
# 326021        False            False            True   warning
# 326022        False            False            True   warning
# 326023        False            False            True   warning
#
#        contraband_found contraband_drugs contraband_weapons  frisk_performed  \
# 0                   NaN              NaN                NaN            False
# 1                   NaN              NaN                NaN            False
# 2                   NaN              NaN                NaN            False
# 3                   NaN              NaN                NaN            False
# 4                   NaN              NaN                NaN            False
# ...                 ...              ...                ...              ...
# 326019            False            False              False            False
# 326020            False            False              False            False
# 326021              NaN              NaN                NaN            False
# 326022              NaN              NaN                NaN            False
# 326023              NaN              NaN                NaN            False
#
#         search_conducted  search_person  search_vehicle    search_basis  \
# 0                  False          False           False             NaN
# 1                  False          False           False             NaN
# 2                  False          False           False             NaN
# 3                  False          False           False             NaN
# 4                  False          False           False             NaN
# ...                  ...            ...             ...             ...
# 326019              True          False           False         consent
# 326020              True           True            True  probable cause
# 326021             False          False           False             NaN
# 326022             False          False           False             NaN
# 326023             False          False           False             NaN
#
#        reason_for_frisk                    reason_for_search  \
# 0                   NaN                                  NaN
# 1                   NaN                                  NaN
# 2                   NaN                                  NaN
# 3                   NaN                                  NaN
# 4                   NaN                                  NaN
# ...                 ...                                  ...
# 326019              NaN           Other Official Information
# 326020              NaN  Observation of Suspected Contraband
# 326021              NaN                                  NaN
# 326022              NaN                                  NaN
# 326023              NaN                                  NaN
#
#                      reason_for_stop raw_Ethnicity raw_Race  \
# 0                      Investigation             N        B
# 1          Stop Light/Sign Violation             H        W
# 2        Vehicle Equipment Violation             N        B
# 3       Vehicle Regulatory Violation             N        B
# 4       Vehicle Regulatory Violation             N        B
# ...                              ...           ...      ...
# 326019     Stop Light/Sign Violation             N        B
# 326020                 Investigation             N        A
# 326021         Speed Limit Violation             N        B
# 326022         Speed Limit Violation             N        B
# 326023         Speed Limit Violation             N        B
#
#        raw_action_description
# 0              Verbal Warning
# 1             Citation Issued
# 2              Verbal Warning
# 3             Citation Issued
# 4             Written Warning
# ...                       ...
# 326019        Citation Issued
# 326020        No Action Taken
# 326021        Written Warning
# 326022        Written Warning
# 326023         Verbal Warning
#
# [326024 rows x 29 columns]

# %%
print(data.shape)
print(data.dtypes)
# Out:
# (326024, 29)
# raw_row_number              int64
# date                       object
# time                       object
# location                   object
# county_name                object
# subject_age               float64
# subject_race               object
# subject_sex                object
# officer_id_hash            object
# department_name            object
# type                       object
# arrest_made                  bool
# citation_issued              bool
# warning_issued               bool
# outcome                    object
# contraband_found           object
# contraband_drugs           object
# contraband_weapons         object
# frisk_performed              bool
# search_conducted             bool
# search_person                bool
# search_vehicle               bool
# search_basis               object
# reason_for_frisk           object
# reason_for_search          object
# reason_for_stop            object
# raw_Ethnicity              object
# raw_Race                   object
# raw_action_description     object
# dtype: object

# %%
data.isnull().sum()
# Out:
# raw_row_number                 0
# date                           0
# time                       48239
# location                       0
# county_name                    0
# subject_age                    7
# subject_race                   1
# subject_sex                    1
# officer_id_hash                0
# department_name                0
# type                           0
# arrest_made                    0
# citation_issued                0
# warning_issued                 0
# outcome                    10782
# contraband_found          304318
# contraband_drugs          304318
# contraband_weapons        304318
# frisk_performed                0
# search_conducted               0
# search_person                  0
# search_vehicle                 0
# search_basis              305092
# reason_for_frisk          325250
# reason_for_search         304318
# reason_for_stop                0
# raw_Ethnicity                  1
# raw_Race                       1
# raw_action_description         0
# dtype: int64

# %%
percent_missing = data.isnull().sum() * 100 / len(data)
missing_value_df = pd.DataFrame({'column_name': data.columns,
                                 'percent_missing': percent_missing})
stat_df = data.describe(include='all').T
stat_df['missing_rate'] = missing_value_df['percent_missing']
stat_df = stat_df.drop(columns = ['count'])
stat_df
# Out:
#                        unique                          top    freq  \
# raw_row_number            NaN                          NaN     NaN
# date                     5112                   2010-01-22     196
# time                    57162                     22:00:00    1006
# location                   96           nan, Durham County  204567
# county_name                12                Durham County  325724
# subject_age               NaN                          NaN     NaN
# subject_race                6                        black  180851
# subject_sex                 2                         male  207853
# officer_id_hash          1642                   5d8b03f925    8367
# department_name             2     Durham Police Department  274996
# type                        1                    vehicular  326024
# arrest_made                 2                        False  318351
# citation_issued             2                         True  168351
# warning_issued              2                        False  186806
# outcome                     3                     citation  168351
# contraband_found            2                        False   16074
# contraband_drugs            2                        False   18615
# contraband_weapons          2                        False   20999
# frisk_performed             2                        False  325250
# search_conducted            2                        False  304318
# search_person               2                        False  306742
# search_vehicle              2                        False  305700
# search_basis                3                      consent   11171
# reason_for_frisk           27          Suspicious Movement     242
# reason_for_search          57  Erratic/Suspicious Behavior    6211
# reason_for_stop            10        Speed Limit Violation  108640
# raw_Ethnicity               2                            N  287055
# raw_Race                    5                            B  181573
# raw_action_description      5              Citation Issued  168351
#
#                                    mean             std        min  \
# raw_row_number          10919159.789267  5464798.410229  1219541.0
# date                                NaN             NaN        NaN
# time                                NaN             NaN        NaN
# location                            NaN             NaN        NaN
# county_name                         NaN             NaN        NaN
# subject_age                   34.894079       12.832317       10.0
# subject_race                        NaN             NaN        NaN
# subject_sex                         NaN             NaN        NaN
# officer_id_hash                     NaN             NaN        NaN
# department_name                     NaN             NaN        NaN
# type                                NaN             NaN        NaN
# arrest_made                         NaN             NaN        NaN
# citation_issued                     NaN             NaN        NaN
# warning_issued                      NaN             NaN        NaN
# outcome                             NaN             NaN        NaN
# contraband_found                    NaN             NaN        NaN
# contraband_drugs                    NaN             NaN        NaN
# contraband_weapons                  NaN             NaN        NaN
# frisk_performed                     NaN             NaN        NaN
# search_conducted                    NaN             NaN        NaN
# search_person                       NaN             NaN        NaN
# search_vehicle                      NaN             NaN        NaN
# search_basis                        NaN             NaN        NaN
# reason_for_frisk                    NaN             NaN        NaN
# reason_for_search                   NaN             NaN        NaN
# reason_for_stop                     NaN             NaN        NaN
# raw_Ethnicity                       NaN             NaN        NaN
# raw_Race                            NaN             NaN        NaN
# raw_action_description              NaN             NaN        NaN
#
#                                25%         50%          75%         max  \
# raw_row_number          6308619.75  11241332.5  15785425.25  20280228.0
# date                           NaN         NaN          NaN         NaN
# time                           NaN         NaN          NaN         NaN
# location                       NaN         NaN          NaN         NaN
# county_name                    NaN         NaN          NaN         NaN
# subject_age                   25.0        32.0         43.0        99.0
# subject_race                   NaN         NaN          NaN         NaN
# subject_sex                    NaN         NaN          NaN         NaN
# officer_id_hash                NaN         NaN          NaN         NaN
# department_name                NaN         NaN          NaN         NaN
# type                           NaN         NaN          NaN         NaN
# arrest_made                    NaN         NaN          NaN         NaN
# citation_issued                NaN         NaN          NaN         NaN
# warning_issued                 NaN         NaN          NaN         NaN
# outcome                        NaN         NaN          NaN         NaN
# contraband_found               NaN         NaN          NaN         NaN
# contraband_drugs               NaN         NaN          NaN         NaN
# contraband_weapons             NaN         NaN          NaN         NaN
# frisk_performed                NaN         NaN          NaN         NaN
# search_conducted               NaN         NaN          NaN         NaN
# search_person                  NaN         NaN          NaN         NaN
# search_vehicle                 NaN         NaN          NaN         NaN
# search_basis                   NaN         NaN          NaN         NaN
# reason_for_frisk               NaN         NaN          NaN         NaN
# reason_for_search              NaN         NaN          NaN         NaN
# reason_for_stop                NaN         NaN          NaN         NaN
# raw_Ethnicity                  NaN         NaN          NaN         NaN
# raw_Race                       NaN         NaN          NaN         NaN
# raw_action_description         NaN         NaN          NaN         NaN
#
#                         missing_rate
# raw_row_number              0.000000
# date                        0.000000
# time                       14.796150
# location                    0.000000
# county_name                 0.000000
# subject_age                 0.002147
# subject_race                0.000307
# subject_sex                 0.000307
# officer_id_hash             0.000000
# department_name             0.000000
# type                        0.000000
# arrest_made                 0.000000
# citation_issued             0.000000
# warning_issued              0.000000
# outcome                     3.307118
# contraband_found           93.342208
# contraband_drugs           93.342208
# contraband_weapons         93.342208
# frisk_performed             0.000000
# search_conducted            0.000000
# search_person               0.000000
# search_vehicle              0.000000
# search_basis               93.579614
# reason_for_frisk           99.762594
# reason_for_search          93.342208
# reason_for_stop             0.000000
# raw_Ethnicity               0.000307
# raw_Race                    0.000307
# raw_action_description      0.000000
