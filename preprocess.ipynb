# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from pathlib import Path

# %%
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
charlotte = pd.read_csv('data/nc_charlotte_2020_04_01.csv')
durham = pd.read_csv('data/nc_durham_2020_04_01.csv')
fayetteville = pd.read_csv('data/nc_fayetteville_2020_04_01.csv')
greensboro = pd.read_csv('data/nc_greensboro_2020_04_01.csv')
raleigh = pd.read_csv('data/nc_raleigh_2020_04_01.csv')
winston_salem = pd.read_csv('data/nc_winston-salem_2020_04_01.csv')
# Out:
# /Users/brandon/opt/anaconda3/envs/cse217a/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
combined = pd.concat([charlotte, durham, fayetteville, greensboro, raleigh, winston_salem], axis=0)
combined = combined.reset_index(drop=True)
combined
# Out:
#          raw_row_number        date      time             location  \
# 0                  3254  2000-01-01  17:20:00              Unknown
# 1                  3259  2000-01-02  11:40:00              Unknown
# 2                  3281  2000-01-02  02:41:00              Unknown
# 3                  3282  2000-01-23  03:35:00              Unknown
# 4                  3283  2000-01-02  16:45:00              Unknown
# ...                 ...         ...       ...                  ...
# 4320461        20278399  2015-12-19  02:27:00  nan, Forsyth County
# 4320462        20278400  2015-12-09  23:38:00  nan, Forsyth County
# 4320463        20278401  2015-12-11  01:24:00  nan, Forsyth County
# 4320464        20278402  2015-12-11  02:21:00  nan, Forsyth County
# 4320465        20278403  2015-12-11  00:36:00  nan, Forsyth County
#
#             county_name  subject_age subject_race subject_sex officer_id_hash  \
# 0                   NaN         38.0        black      female      22e35044ed
# 1                   NaN         33.0     hispanic        male      22e35044ed
# 2                   NaN         23.0        white        male      22e35044ed
# 3                   NaN         23.0        white      female      22e35044ed
# 4                   NaN         23.0        white      female      22e35044ed
# ...                 ...          ...          ...         ...             ...
# 4320461  Forsyth County         24.0        black        male      0a7f06db99
# 4320462  Forsyth County         37.0        black        male      223001a5be
# 4320463  Forsyth County         21.0     hispanic        male      b17198e1b4
# 4320464  Forsyth County         27.0        white        male      0f4172ddc4
# 4320465  Forsyth County         42.0        black        male      c579308c2c
#
#                                     department_name       type  arrest_made  \
# 0        UNC Charlotte University Police Department  vehicular        False
# 1        UNC Charlotte University Police Department  vehicular        False
# 2        UNC Charlotte University Police Department  vehicular        False
# 3        UNC Charlotte University Police Department  vehicular        False
# 4        UNC Charlotte University Police Department  vehicular        False
# ...                                             ...        ...          ...
# 4320461             Winston-Salem Police Department  vehicular        False
# 4320462             Winston-Salem Police Department  vehicular        False
# 4320463             Winston-Salem Police Department  vehicular         True
# 4320464             Winston-Salem Police Department  vehicular         True
# 4320465             Winston-Salem Police Department  vehicular        False
#
#          citation_issued  warning_issued   outcome contraband_found  \
# 0                  False            True   warning              NaN
# 1                   True           False  citation              NaN
# 2                   True           False  citation              NaN
# 3                   True           False  citation              NaN
# 4                  False            True   warning              NaN
# ...                  ...             ...       ...              ...
# 4320461             True           False  citation             True
# 4320462             True           False  citation             True
# 4320463            False           False    arrest            False
# 4320464            False           False    arrest            False
# 4320465             True           False  citation            False
#
#         contraband_drugs contraband_weapons  frisk_performed  \
# 0                    NaN                NaN            False
# 1                    NaN                NaN            False
# 2                    NaN                NaN            False
# 3                    NaN                NaN            False
# 4                    NaN                NaN            False
# ...                  ...                ...              ...
# 4320461             True              False            False
# 4320462             True              False            False
# 4320463            False              False            False
# 4320464            False              False            False
# 4320465            False              False            False
#
#          search_conducted  search_person  search_vehicle    search_basis  \
# 0                   False          False           False             NaN
# 1                   False          False           False             NaN
# 2                   False          False           False             NaN
# 3                   False          False           False             NaN
# 4                   False          False           False             NaN
# ...                   ...            ...             ...             ...
# 4320461              True           True            True  probable cause
# 4320462              True           True            True  probable cause
# 4320463              True           True            True           other
# 4320464              True           True            True  probable cause
# 4320465              True          False            True         consent
#
#         reason_for_frisk                    reason_for_search  \
# 0                    NaN                                  NaN
# 1                    NaN                                  NaN
# 2                    NaN                                  NaN
# 3                    NaN                                  NaN
# 4                    NaN                                  NaN
# ...                  ...                                  ...
# 4320461              NaN  Observation of Suspected Contraband
# 4320462              NaN           Other Official Information
# 4320463              NaN  Observation of Suspected Contraband
# 4320464              NaN           Other Official Information
# 4320465              NaN           Other Official Information
#
#                        reason_for_stop raw_Ethnicity raw_Race  \
# 0              Safe Movement Violation             N        B
# 1         Vehicle Regulatory Violation             H        W
# 2          Vehicle Equipment Violation             N        W
# 3         Vehicle Regulatory Violation             N        W
# 4              Safe Movement Violation             N        W
# ...                                ...           ...      ...
# 4320461  Other Motor Vehicle Violation             N        B
# 4320462    Vehicle Equipment Violation             N        B
# 4320463    Vehicle Equipment Violation             H        W
# 4320464         Driving While Impaired             N        W
# 4320465            Seat Belt Violation             N        B
#
#         raw_action_description
# 0               Verbal Warning
# 1              Citation Issued
# 2              Citation Issued
# 3              Citation Issued
# 4               Verbal Warning
# ...                        ...
# 4320461        Citation Issued
# 4320462        Citation Issued
# 4320463         On-View Arrest
# 4320464         On-View Arrest
# 4320465        Citation Issued
#
# [4320466 rows x 29 columns]

# %% [markdown]
# ## Save train and test as csv files

# %%
train, test = train_test_split(combined, test_size=0.2, 
                               stratify = combined['department_name']) # stratify according to county

# %%
train_filepath = Path('train.csv')  
train_filepath.parent.mkdir(parents=True, exist_ok=True)  
train.to_csv(train_filepath, index = False)

test_filepath = Path('test.csv')  
test_filepath.parent.mkdir(parents=True, exist_ok=True)  
test.to_csv(test_filepath, index = False)

# %% [markdown]
# ## Drop Missing Rate > 95%

# %%
def drop_high_missing_rate(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_value_df = pd.DataFrame({'column_name': df.columns,
                                     'percent_missing': percent_missing})
    stat_df = df.describe(include='all').T
    stat_df['missing_rate'] = missing_value_df['percent_missing']
    stat_df = stat_df.drop(columns = ['count'])
    
    high_missing_rate = stat_df[stat_df.missing_rate > 95].index.values
    df = df.drop(high_missing_rate, axis=1)
    
    return df

processed_train = drop_high_missing_rate(train).reset_index(drop=True)
processed_train
# Out:
#          raw_row_number        date      time  \
# 0              13898103  2011-10-14  13:10:00
# 1              16635989  2013-01-06  18:48:00
# 2               3644747  2003-07-25       NaN
# 3               4231260  2004-06-23  11:28:00
# 4              19082891  2015-01-18  01:51:00
# ...                 ...         ...       ...
# 3456367        19335192  2015-04-18  09:45:00
# 3456368        14991256  2012-05-18  11:10:00
# 3456369         6127358  2006-07-12  21:33:00
# 3456370         2773870  2003-03-24  14:35:00
# 3456371         2657397  2003-01-27  14:00:00
#
#                                    location         county_name  subject_age  \
# 0        Charlotte Area, Mecklenburg County  Mecklenburg County         41.0
# 1                       nan, Forsyth County      Forsyth County         36.0
# 2                          , Forsyth County      Forsyth County         20.0
# 3                      RALEIGH, Wake County         Wake County         29.0
# 4                      RALEIGH, Wake County         Wake County         27.0
# ...                                     ...                 ...          ...
# 3456367                RALEIGH, Wake County         Wake County         58.0
# 3456368                  nan, Durham County       Durham County         63.0
# 3456369  Charlotte Area, Mecklenburg County  Mecklenburg County         22.0
# 3456370          GREE04102, Guilford County     Guilford County         30.0
# 3456371  Charlotte Area, Mecklenburg County  Mecklenburg County         33.0
#
#         subject_race subject_sex officer_id_hash  \
# 0              white      female      d1e8da930a
# 1              black        male      da4269670d
# 2           hispanic        male      40f7ef4db6
# 3              black      female      db839dfc32
# 4              white        male      b152422867
# ...              ...         ...             ...
# 3456367        white        male      599f5d18f7
# 3456368        black        male      7a89a58beb
# 3456369        black        male      11b0ef1d58
# 3456370        black      female      8f589487ed
# 3456371        white        male      47074400a0
#
#                                  department_name       type  arrest_made  \
# 0        Charlotte-Mecklenburg Police Department  vehicular        False
# 1                Winston-Salem Police Department  vehicular        False
# 2                Winston-Salem Police Department  vehicular        False
# 3                      Raleigh Police Department  vehicular        False
# 4                      Raleigh Police Department  vehicular         True
# ...                                          ...        ...          ...
# 3456367                Raleigh Police Department  vehicular        False
# 3456368                 Durham Police Department  vehicular        False
# 3456369  Charlotte-Mecklenburg Police Department  vehicular         True
# 3456370             Greensboro Police Department  vehicular        False
# 3456371  Charlotte-Mecklenburg Police Department  vehicular        False
#
#          citation_issued  warning_issued   outcome  frisk_performed  \
# 0                   True           False  citation            False
# 1                  False            True   warning            False
# 2                   True           False  citation            False
# 3                   True           False  citation            False
# 4                  False           False    arrest            False
# ...                  ...             ...       ...              ...
# 3456367            False            True   warning            False
# 3456368             True           False  citation            False
# 3456369            False           False    arrest            False
# 3456370             True           False  citation            False
# 3456371             True           False  citation            False
#
#          search_conducted  search_person  search_vehicle  \
# 0                   False          False           False
# 1                   False          False           False
# 2                   False          False           False
# 3                   False          False           False
# 4                    True           True            True
# ...                   ...            ...             ...
# 3456367             False          False           False
# 3456368             False          False           False
# 3456369              True           True            True
# 3456370             False          False           False
# 3456371             False          False           False
#
#                        reason_for_stop raw_Ethnicity raw_Race  \
# 0         Vehicle Regulatory Violation             N        W
# 1              Safe Movement Violation             N        B
# 2         Vehicle Regulatory Violation             H        U
# 3                Speed Limit Violation             N        B
# 4               Driving While Impaired             N        W
# ...                                ...           ...      ...
# 3456367   Vehicle Regulatory Violation             N        W
# 3456368          Speed Limit Violation             N        B
# 3456369  Other Motor Vehicle Violation             N        B
# 3456370          Speed Limit Violation             N        B
# 3456371   Vehicle Regulatory Violation             N        W
#
#         raw_action_description
# 0              Citation Issued
# 1               Verbal Warning
# 2              Citation Issued
# 3              Citation Issued
# 4               On-View Arrest
# ...                        ...
# 3456367         Verbal Warning
# 3456368        Citation Issued
# 3456369         On-View Arrest
# 3456370        Citation Issued
# 3456371        Citation Issued
#
# [3456372 rows x 23 columns]

# %% [markdown]
# ## Preprocessing - combine date and time

# %%
def to_date_time(df):
    date_time = pd.to_datetime(df['date'] + df['time'], 
                               format='%Y-%m-%d%H:%M:%S') # allow comparing date time
    df['date_time'] = date_time
    df = df.drop(['date','time'],axis=1)
    
    return df

processed_train = to_date_time(processed_train)
processed_train
# Out:
#          raw_row_number                            location  \
# 0              13898103  Charlotte Area, Mecklenburg County
# 1              16635989                 nan, Forsyth County
# 2               3644747                    , Forsyth County
# 3               4231260                RALEIGH, Wake County
# 4              19082891                RALEIGH, Wake County
# ...                 ...                                 ...
# 3456367        19335192                RALEIGH, Wake County
# 3456368        14991256                  nan, Durham County
# 3456369         6127358  Charlotte Area, Mecklenburg County
# 3456370         2773870          GREE04102, Guilford County
# 3456371         2657397  Charlotte Area, Mecklenburg County
#
#                 county_name  subject_age subject_race subject_sex  \
# 0        Mecklenburg County         41.0        white      female
# 1            Forsyth County         36.0        black        male
# 2            Forsyth County         20.0     hispanic        male
# 3               Wake County         29.0        black      female
# 4               Wake County         27.0        white        male
# ...                     ...          ...          ...         ...
# 3456367         Wake County         58.0        white        male
# 3456368       Durham County         63.0        black        male
# 3456369  Mecklenburg County         22.0        black        male
# 3456370     Guilford County         30.0        black      female
# 3456371  Mecklenburg County         33.0        white        male
#
#         officer_id_hash                          department_name       type  \
# 0            d1e8da930a  Charlotte-Mecklenburg Police Department  vehicular
# 1            da4269670d          Winston-Salem Police Department  vehicular
# 2            40f7ef4db6          Winston-Salem Police Department  vehicular
# 3            db839dfc32                Raleigh Police Department  vehicular
# 4            b152422867                Raleigh Police Department  vehicular
# ...                 ...                                      ...        ...
# 3456367      599f5d18f7                Raleigh Police Department  vehicular
# 3456368      7a89a58beb                 Durham Police Department  vehicular
# 3456369      11b0ef1d58  Charlotte-Mecklenburg Police Department  vehicular
# 3456370      8f589487ed             Greensboro Police Department  vehicular
# 3456371      47074400a0  Charlotte-Mecklenburg Police Department  vehicular
#
#          arrest_made  citation_issued  warning_issued   outcome  \
# 0              False             True           False  citation
# 1              False            False            True   warning
# 2              False             True           False  citation
# 3              False             True           False  citation
# 4               True            False           False    arrest
# ...              ...              ...             ...       ...
# 3456367        False            False            True   warning
# 3456368        False             True           False  citation
# 3456369         True            False           False    arrest
# 3456370        False             True           False  citation
# 3456371        False             True           False  citation
#
#          frisk_performed  search_conducted  search_person  search_vehicle  \
# 0                  False             False          False           False
# 1                  False             False          False           False
# 2                  False             False          False           False
# 3                  False             False          False           False
# 4                  False              True           True            True
# ...                  ...               ...            ...             ...
# 3456367            False             False          False           False
# 3456368            False             False          False           False
# 3456369            False              True           True            True
# 3456370            False             False          False           False
# 3456371            False             False          False           False
#
#                        reason_for_stop raw_Ethnicity raw_Race  \
# 0         Vehicle Regulatory Violation             N        W
# 1              Safe Movement Violation             N        B
# 2         Vehicle Regulatory Violation             H        U
# 3                Speed Limit Violation             N        B
# 4               Driving While Impaired             N        W
# ...                                ...           ...      ...
# 3456367   Vehicle Regulatory Violation             N        W
# 3456368          Speed Limit Violation             N        B
# 3456369  Other Motor Vehicle Violation             N        B
# 3456370          Speed Limit Violation             N        B
# 3456371   Vehicle Regulatory Violation             N        W
#
#         raw_action_description           date_time
# 0              Citation Issued 2011-10-14 13:10:00
# 1               Verbal Warning 2013-01-06 18:48:00
# 2              Citation Issued                 NaT
# 3              Citation Issued 2004-06-23 11:28:00
# 4               On-View Arrest 2015-01-18 01:51:00
# ...                        ...                 ...
# 3456367         Verbal Warning 2015-04-18 09:45:00
# 3456368        Citation Issued 2012-05-18 11:10:00
# 3456369         On-View Arrest 2006-07-12 21:33:00
# 3456370        Citation Issued 2003-03-24 14:35:00
# 3456371        Citation Issued 2003-01-27 14:00:00
#
# [3456372 rows x 22 columns]

# %% [markdown]
# ## Fill NA

# %%
def fillna(df):
    for col in df.columns:
        if col == 'subject_age':
            df[col].fillna(df[col].mean(), inplace = True) # for numeric, fill mean
        else:
            df[col].fillna(df[col].mode().values[0], inplace = True) # for categoric fill mode
    return df
processed_train = fillna(processed_train)
processed_train
# Out:
#          raw_row_number                            location  \
# 0              13898103  Charlotte Area, Mecklenburg County
# 1              16635989                 nan, Forsyth County
# 2               3644747                    , Forsyth County
# 3               4231260                RALEIGH, Wake County
# 4              19082891                RALEIGH, Wake County
# ...                 ...                                 ...
# 3456367        19335192                RALEIGH, Wake County
# 3456368        14991256                  nan, Durham County
# 3456369         6127358  Charlotte Area, Mecklenburg County
# 3456370         2773870          GREE04102, Guilford County
# 3456371         2657397  Charlotte Area, Mecklenburg County
#
#                 county_name  subject_age subject_race subject_sex  \
# 0        Mecklenburg County         41.0        white      female
# 1            Forsyth County         36.0        black        male
# 2            Forsyth County         20.0     hispanic        male
# 3               Wake County         29.0        black      female
# 4               Wake County         27.0        white        male
# ...                     ...          ...          ...         ...
# 3456367         Wake County         58.0        white        male
# 3456368       Durham County         63.0        black        male
# 3456369  Mecklenburg County         22.0        black        male
# 3456370     Guilford County         30.0        black      female
# 3456371  Mecklenburg County         33.0        white        male
#
#         officer_id_hash                          department_name       type  \
# 0            d1e8da930a  Charlotte-Mecklenburg Police Department  vehicular
# 1            da4269670d          Winston-Salem Police Department  vehicular
# 2            40f7ef4db6          Winston-Salem Police Department  vehicular
# 3            db839dfc32                Raleigh Police Department  vehicular
# 4            b152422867                Raleigh Police Department  vehicular
# ...                 ...                                      ...        ...
# 3456367      599f5d18f7                Raleigh Police Department  vehicular
# 3456368      7a89a58beb                 Durham Police Department  vehicular
# 3456369      11b0ef1d58  Charlotte-Mecklenburg Police Department  vehicular
# 3456370      8f589487ed             Greensboro Police Department  vehicular
# 3456371      47074400a0  Charlotte-Mecklenburg Police Department  vehicular
#
#          arrest_made  citation_issued  warning_issued   outcome  \
# 0              False             True           False  citation
# 1              False            False            True   warning
# 2              False             True           False  citation
# 3              False             True           False  citation
# 4               True            False           False    arrest
# ...              ...              ...             ...       ...
# 3456367        False            False            True   warning
# 3456368        False             True           False  citation
# 3456369         True            False           False    arrest
# 3456370        False             True           False  citation
# 3456371        False             True           False  citation
#
#          frisk_performed  search_conducted  search_person  search_vehicle  \
# 0                  False             False          False           False
# 1                  False             False          False           False
# 2                  False             False          False           False
# 3                  False             False          False           False
# 4                  False              True           True            True
# ...                  ...               ...            ...             ...
# 3456367            False             False          False           False
# 3456368            False             False          False           False
# 3456369            False              True           True            True
# 3456370            False             False          False           False
# 3456371            False             False          False           False
#
#                        reason_for_stop raw_Ethnicity raw_Race  \
# 0         Vehicle Regulatory Violation             N        W
# 1              Safe Movement Violation             N        B
# 2         Vehicle Regulatory Violation             H        U
# 3                Speed Limit Violation             N        B
# 4               Driving While Impaired             N        W
# ...                                ...           ...      ...
# 3456367   Vehicle Regulatory Violation             N        W
# 3456368          Speed Limit Violation             N        B
# 3456369  Other Motor Vehicle Violation             N        B
# 3456370          Speed Limit Violation             N        B
# 3456371   Vehicle Regulatory Violation             N        W
#
#         raw_action_description           date_time
# 0              Citation Issued 2011-10-14 13:10:00
# 1               Verbal Warning 2013-01-06 18:48:00
# 2              Citation Issued 2008-07-22 12:06:29
# 3              Citation Issued 2004-06-23 11:28:00
# 4               On-View Arrest 2015-01-18 01:51:00
# ...                        ...                 ...
# 3456367         Verbal Warning 2015-04-18 09:45:00
# 3456368        Citation Issued 2012-05-18 11:10:00
# 3456369         On-View Arrest 2006-07-12 21:33:00
# 3456370        Citation Issued 2003-03-24 14:35:00
# 3456371        Citation Issued 2003-01-27 14:00:00
#
# [3456372 rows x 22 columns]

# %% [markdown]
# ## Save processed_train as csv

# %%
train_filepath = Path('processed_train.csv')  
train_filepath.parent.mkdir(parents=True, exist_ok=True)  
processed_train.to_csv(train_filepath, index = False)
